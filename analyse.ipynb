# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
import keras
from keras import metrics
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation
import os
import pickle
import cv2
import imutils
from imutils.contours import sort_contours

from src import fonctions

# %%
model = load_model("data/model.h5")
print("Modèle chargé!")
# Out:
# Modèle chargé!

# %%
choix = r"assets\tigre.jpg"
test_image = image.load_img(choix, target_size = (64,64), grayscale = True)
plt.imshow(test_image)
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)

# %%
resultat = model.predict(test_image)
resultat = fonctions.get_result(resultat)
print(f"La catégorie correspondante est: {resultat}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f5f1c4653efe> in <module>
# ----> 1 resultat = model.predict(test_image)
#       2 resultat = fonctions.get_result(resultat)
#       3 print(f"La catégorie correspondante est: {resultat}")
#
# ~\anaconda3\envs\opencv\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1439
#    1440         # Case 2: Symbolic tensors or Numpy array-like.
# -> 1441         x, _, _ = self._standardize_user_data(x)
#    1442         if self.stateful:
#    1443             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~\anaconda3\envs\opencv\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
# ...
