# %%
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from PIL import Image

import matplotlib.pyplot as plt

import modules.images.utils as im

# %%
# Model configuration
TRAIN_DATA_DIR = 'data/cifar-100-test/train'
TEST_DATA_DIR = 'data/cifar-100-test/test'
TRAIN_IMAGE_SIZE = 32
TRAIN_BATCH_SIZE = 50
batch_size = 50
img_width, img_height, img_num_channels = 32, 32, 3
no_classes = 2
no_epochs = 50
validation_split = 0.3
verbosity = 1

# Determine shape of the data
input_shape = (img_width, img_height, img_num_channels)

# %%
image_data_generator = tf.keras.preprocessing.image.ImageDataGenerator(validation_split=validation_split)

train_generator = image_data_generator.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=(TRAIN_IMAGE_SIZE, TRAIN_IMAGE_SIZE),
    batch_size=TRAIN_BATCH_SIZE,
    class_mode='categorical',
    subset='training')
 
validation_generator = image_data_generator.flow_from_directory(
    TRAIN_DATA_DIR, # same directory as training data
    target_size=(TRAIN_IMAGE_SIZE, TRAIN_IMAGE_SIZE),
    batch_size=TRAIN_BATCH_SIZE,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 700 images belonging to 2 classes.
# Found 300 images belonging to 2 classes.

# %%
# Create the model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3),padding='same', activation='relu', input_shape=input_shape))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Conv2D(8, kernel_size=(3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dense(128, activation='relu'))
model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 131074
# =================================================================
# Total params: 150,466
# Trainable params: 150,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
training = model.fit_generator(train_generator, epochs=no_epochs, validation_data=validation_generator)
# Out:
# Epoch 1/50
# 14/14 [==============================] - 8s 540ms/step - loss: 122.8262 - accuracy: 0.5500 - val_loss: 6.9158 - val_accuracy: 0.7067
# Epoch 2/50
# 14/14 [==============================] - 6s 455ms/step - loss: 1.6097 - accuracy: 0.8157 - val_loss: 0.6229 - val_accuracy: 0.8200
# Epoch 3/50
# 14/14 [==============================] - 7s 474ms/step - loss: 0.3648 - accuracy: 0.8600 - val_loss: 0.5202 - val_accuracy: 0.7967
# Epoch 4/50
# 14/14 [==============================] - 6s 463ms/step - loss: 0.2127 - accuracy: 0.9114 - val_loss: 0.5575 - val_accuracy: 0.8400
# Epoch 5/50
# 14/14 [==============================] - 6s 450ms/step - loss: 0.1296 - accuracy: 0.9457 - val_loss: 0.6172 - val_accuracy: 0.8600
# Epoch 6/50
# 14/14 [==============================] - 7s 476ms/step - loss: 0.0709 - accuracy: 0.9743 - val_loss: 0.5926 - val_accuracy: 0.8800
# Epoch 7/50
# 14/14 [==============================] - 6s 463ms/step - loss: 0.0444 - accuracy: 0.9843 - val_loss: 0.6144 - val_accuracy: 0.8433
# Epoch 8/50
# 14/14 [==============================] - 6s 459ms/step - loss: 0.0423 - accuracy: 0.9843 - val_loss: 0.6171 - val_accuracy: 0.8800
# Epoch 9/50
# 14/14 [==============================] - 7s 488ms/step - loss: 0.0257 - accuracy: 0.9943 - val_loss: 0.6727 - val_accuracy: 0.8567
# Epoch 10/50
# 14/14 [==============================] - 7s 478ms/step - loss: 0.0158 - accuracy: 0.9971 - val_loss: 0.8160 - val_accuracy: 0.8733
# Epoch 11/50
# 14/14 [==============================] - 7s 466ms/step - loss: 0.0098 - accuracy: 0.9986 - val_loss: 0.8608 - val_accuracy: 0.8667
# Epoch 12/50
# 14/14 [==============================] - 7s 480ms/step - loss: 0.0073 - accuracy: 0.9986 - val_loss: 0.8154 - val_accuracy: 0.8700
# Epoch 13/50
# 14/14 [==============================] - 7s 500ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.8594 - val_accuracy: 0.8767
# Epoch 14/50
# 14/14 [==============================] - 6s 456ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.8744 - val_accuracy: 0.8867
# Epoch 15/50
# 14/14 [==============================] - 6s 459ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.9043 - val_accuracy: 0.8833
# Epoch 16/50
# 14/14 [==============================] - 6s 461ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.8958 - val_accuracy: 0.8800
# Epoch 17/50
# 14/14 [==============================] - 6s 459ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.9061 - val_accuracy: 0.8833
# Epoch 18/50
# 14/14 [==============================] - 7s 466ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.9303 - val_accuracy: 0.8833
# Epoch 19/50
# 14/14 [==============================] - 6s 457ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.9374 - val_accuracy: 0.8800
# Epoch 20/50
# 14/14 [==============================] - 7s 490ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.9501 - val_accuracy: 0.8900
# Epoch 21/50
# 14/14 [==============================] - 7s 466ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.9600 - val_accuracy: 0.8900
# Epoch 22/50
# 14/14 [==============================] - 7s 475ms/step - loss: 9.9423e-04 - accuracy: 1.0000 - val_loss: 0.9615 - val_accuracy: 0.8867
# Epoch 23/50
# 14/14 [==============================] - 7s 486ms/step - loss: 9.1144e-04 - accuracy: 1.0000 - val_loss: 0.9915 - val_accuracy: 0.8867
# Epoch 24/50
# 14/14 [==============================] - 7s 501ms/step - loss: 8.1398e-04 - accuracy: 1.0000 - val_loss: 0.9890 - val_accuracy: 0.8933
# Epoch 25/50
# 14/14 [==============================] - 6s 415ms/step - loss: 6.9908e-04 - accuracy: 1.0000 - val_loss: 1.0012 - val_accuracy: 0.8867
# Epoch 26/50
# 14/14 [==============================] - 6s 400ms/step - loss: 6.5078e-04 - accuracy: 1.0000 - val_loss: 1.0196 - val_accuracy: 0.8867
# Epoch 27/50
# 14/14 [==============================] - 6s 410ms/step - loss: 6.1975e-04 - accuracy: 1.0000 - val_loss: 1.0298 - val_accuracy: 0.8833
# Epoch 28/50
# 14/14 [==============================] - 6s 395ms/step - loss: 5.2378e-04 - accuracy: 1.0000 - val_loss: 1.0438 - val_accuracy: 0.8833
# Epoch 29/50
# 14/14 [==============================] - 6s 398ms/step - loss: 5.2766e-04 - accuracy: 1.0000 - val_loss: 1.0337 - val_accuracy: 0.8867
# Epoch 30/50
# 14/14 [==============================] - 6s 404ms/step - loss: 5.3796e-04 - accuracy: 1.0000 - val_loss: 1.0490 - val_accuracy: 0.8833
# Epoch 31/50
# 14/14 [==============================] - 6s 399ms/step - loss: 4.2059e-04 - accuracy: 1.0000 - val_loss: 1.0703 - val_accuracy: 0.8833
# Epoch 32/50
# 14/14 [==============================] - 5s 391ms/step - loss: 3.7729e-04 - accuracy: 1.0000 - val_loss: 1.0661 - val_accuracy: 0.8833
# Epoch 33/50
# 14/14 [==============================] - 6s 401ms/step - loss: 3.5002e-04 - accuracy: 1.0000 - val_loss: 1.0686 - val_accuracy: 0.8833
# Epoch 34/50
# 14/14 [==============================] - 6s 431ms/step - loss: 3.2058e-04 - accuracy: 1.0000 - val_loss: 1.0877 - val_accuracy: 0.8833
# Epoch 35/50
# 14/14 [==============================] - 6s 410ms/step - loss: 3.0665e-04 - accuracy: 1.0000 - val_loss: 1.0868 - val_accuracy: 0.8833
# Epoch 36/50
# 14/14 [==============================] - 6s 409ms/step - loss: 2.7702e-04 - accuracy: 1.0000 - val_loss: 1.1022 - val_accuracy: 0.8733
# Epoch 37/50
# 14/14 [==============================] - 6s 398ms/step - loss: 2.5027e-04 - accuracy: 1.0000 - val_loss: 1.1111 - val_accuracy: 0.8733
# Epoch 38/50
# 14/14 [==============================] - 6s 403ms/step - loss: 2.4596e-04 - accuracy: 1.0000 - val_loss: 1.1303 - val_accuracy: 0.8733
# Epoch 39/50
# 14/14 [==============================] - 6s 394ms/step - loss: 2.1895e-04 - accuracy: 1.0000 - val_loss: 1.1312 - val_accuracy: 0.8767
# Epoch 40/50
# 14/14 [==============================] - 6s 433ms/step - loss: 1.9736e-04 - accuracy: 1.0000 - val_loss: 1.1277 - val_accuracy: 0.8700
# Epoch 41/50
# 14/14 [==============================] - 6s 453ms/step - loss: 1.8518e-04 - accuracy: 1.0000 - val_loss: 1.1422 - val_accuracy: 0.8733
# Epoch 42/50
# 14/14 [==============================] - 6s 413ms/step - loss: 1.6675e-04 - accuracy: 1.0000 - val_loss: 1.1423 - val_accuracy: 0.8700
# Epoch 43/50
# 14/14 [==============================] - 6s 409ms/step - loss: 1.6667e-04 - accuracy: 1.0000 - val_loss: 1.1563 - val_accuracy: 0.8767
# Epoch 44/50
# 14/14 [==============================] - 6s 398ms/step - loss: 1.4741e-04 - accuracy: 1.0000 - val_loss: 1.1557 - val_accuracy: 0.8700
# Epoch 45/50
# 14/14 [==============================] - 6s 432ms/step - loss: 1.3135e-04 - accuracy: 1.0000 - val_loss: 1.1799 - val_accuracy: 0.8767
# Epoch 46/50
# 14/14 [==============================] - 6s 407ms/step - loss: 1.3045e-04 - accuracy: 1.0000 - val_loss: 1.1721 - val_accuracy: 0.8767
# Epoch 47/50
# 14/14 [==============================] - 6s 403ms/step - loss: 1.1590e-04 - accuracy: 1.0000 - val_loss: 1.1845 - val_accuracy: 0.8733
# Epoch 48/50
# 14/14 [==============================] - 6s 396ms/step - loss: 1.1031e-04 - accuracy: 1.0000 - val_loss: 1.1867 - val_accuracy: 0.8733
# Epoch 49/50
# 14/14 [==============================] - 6s 413ms/step - loss: 9.9938e-05 - accuracy: 1.0000 - val_loss: 1.1888 - val_accuracy: 0.8767
# Epoch 50/50
# 14/14 [==============================] - 6s 400ms/step - loss: 9.4378e-05 - accuracy: 1.0000 - val_loss: 1.1978 - val_accuracy: 0.8733

# %%
# Visualize history
# Plot history: Loss
# plt.plot(training.history['val_loss'])
# plt.title('Validation loss history')
# plt.ylabel('Loss value')
# plt.xlabel('No. epoch')
# plt.show()

# %%
# Visualize history
# Plot history: Loss
# plt.plot(training.history['loss'])
# plt.title('Validation loss history')
# plt.ylabel('Loss value')
# plt.xlabel('No. epoch')
# plt.show()

# %%
# # Plot history: Accuracy
# plt.plot(training.history['val_accuracy'])
# plt.title('Validation accuracy history')
# plt.ylabel('Accuracy value (%)')
# plt.xlabel('No. epoch')
# plt.show()

# %%
plt.plot(training.history['loss'], color='red', label='Training loss')
plt.plot(training.history['val_loss'],  color='green', label='Validation loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.show()

# %%
plt.plot(training.history['accuracy'], color='red', label='Training accuracy')
plt.plot(training.history['val_accuracy'],  color='green', label='Validation accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.show()

# %%
from keras.models import Model
from keras.preprocessing import image
import numpy as np

layer_outputs = [layer.output for layer in model.layers]

test_image = "data/cifar-100-test/test/apple/0014.png"

# Le chargement de l'image doit être augmenté puisque notre model prend des lots d'images.
img = image.load_img(test_image, target_size=(32,32, 3))
img_arr = image.img_to_array(img)
img_arr = np.expand_dims(img_arr, axis=0)

activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(img_arr)

def display_activation(activations, col_size, row_size, act_index): 
    activation = activations[act_index]
    activation_index=0
    fig, ax = plt.subplots(row_size, col_size, figsize=(row_size*13.5,col_size*2.5))
    for row in range(0,row_size):
        for col in range(0,col_size):
            ax[row][col].imshow(activation[0, :, :, activation_index], cmap='plasma')
            activation_index += 1

# %%
display_activation(activations, 8, 4, 0)

# %%
display_activation(activations, 8, 4, 1)
